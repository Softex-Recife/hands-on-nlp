# %% [markdown]
# #Primeira configuração

# %% [markdown]
# ## Carregando as bibliotecas iniciais

# %% [markdown]
# [Pandas](https://pandas.pydata.org/) é uma biblioteca para trabalhar com bases de dados, permite o manuseio e a análise de maneira simples.
# <br />
# [Spacy](https://spacy.io/) é utilizada para o pré-processamento do texto para ser inserido em um algoritmo de Inteligencia Artifical (IA).

# %%
import pandas as pd
import spacy

# %% [markdown]
# ## Configurando spacy

# %% [markdown]
# Configuração para inglês.

# %%
nlp = spacy.load("en")

# %% [markdown]
# Configuração para português (a utilizada nesse notebook).

# %%
spacy.cli.download("pt")
nlp = spacy.load("pt")
# Out:
#     Linking successful
#     /usr/local/lib/python3.6/dist-packages/pt_core_news_sm -->
#     /usr/local/lib/python3.6/dist-packages/spacy/data/pt
#
#     You can now load the model via spacy.load('pt')

# %% [markdown]
# ## Carregando a base e dando uma olhada nela

# %% [markdown]
# O comando `read_csv()` é utilizado para carregar a base de dados e um objeto do tipo **Dataframe** é retornado.
# <br />
# Já o comando `head()` é útil para primeira análisa na base pois retorna as 5 primeiras linhas do documento.

# %%
tweets_df = pd.read_csv("https://raw.githubusercontent.com/Softex-Recife/hands-on-nlp/master/corpora/balanced_four_class.csv", sep=";", header=None)
tweets_df.head()
# Out:
#          0                1           2      3   ...   21   22   23   24
# 0  Positivo  Banco do Brasil         NaN    Sim  ...  NaN  NaN  NaN  NaN
# 1  Positivo  Banco do Brasil         NaN    NaN  ...  NaN  NaN  NaN  NaN
# 2  Positivo  Banco do Brasil  Propaganda  False  ...  NaN  NaN  NaN  NaN
# 3  Positivo  Banco do Brasil       Banco   True  ...  NaN  NaN  NaN  NaN
# 4  Positivo  Banco do Brasil       Banco    NaN  ...  NaN  NaN  NaN  NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Selecionando as colunas

# %% [markdown]
# O foco deste notebook é a classificação de texto somente, por isso precisamos selecionar somente as colunas que contém o **texto** e o **sentimento**.
# <br />
# As colunas são extraídas utilizando o comando `iloc[]` passando os parâmetros ":" e o número correspondente à coluna desejada, um objeto do tipo **Serie** é retornado.
# <br />
# Com as duas colunas selecionadas, é construído um novo **DataFrame** (`DataFrame({"text": texts, "sentiment": sentiments})`).

# %%
sentiments = tweets_df.iloc[:, 0]
texts = tweets_df.iloc[:, 14]
tweets_df = pd.DataFrame({"text": texts, "sentiment": sentiments})
tweets_df.head()
# Out:
#                                                 text sentiment
# 0  Obrigada pela homenagem ao #casamentoigualitar...  Positivo
# 1  O #BancoDoBrasil já me deixou uma mensagem de ...  Positivo
# 2  Bora ser seu próprio chefe, trabalhar com espo...  Positivo
# 3  HAHAHAHA @BancodoBrasil maravilhoso!!!! http:/...  Positivo
# 4  Parabens ao @BancodoBrasil #circuitobancodobra...  Positivo

# %% [markdown]
# #Spacy
#
# ---

# %% [markdown]
# Para demonstrar um pouco do poder do spacy vamos exercutar os seus comandos mais famosos.

# %% [markdown]
# ##Detectando sentenças

# %% [markdown]
# Separamos somente as 5 primeiras frazes contidas na nossa base para demonstração (`tweets_df["text"][:5]`), cada uma dessas frases são apliacadas no spacy e um objeto **Document** é retornado, a separação das sentenças é feita através do atributo **sents** (`doc.sents`).

# %%
#frases de exemplo
sentences_example = tweets_df["text"][:5]
for sentence in sentences_example:
  doc = nlp(sentence)
  sentences = [token for token in doc.sents]
  print (sentences)
# Out:
# [Obrigada pela homenagem ao #casamentoigualitario , @BancodoBrasil @BancoDoBrasil7  !!, Vejam aqui:, http://t.co/4hICRrgnrW !, Muito bom!]
# [O #BancoDoBrasil já me deixou uma mensagem de parabéns., O 1º.]
# [Bora ser seu próprio chefe, trabalhar com esportes e ganhar 20 mil reais?, A #InterU e o @BancoDoBrasil explicam como: http://t.co/ZgbqthSluF]
# [HAHAHAHA @BancodoBrasil maravilhoso!!!, !, http://t.co/mscHrnWiA4]
# [Parabens ao @BancodoBrasil #circuitobancodobrasil por um evento desse nivel!, Esse banco tem historia no esporte!, http://t.co/GBHjhVCIxu]

# %% [markdown]
# ## Remoção de Stop Words e Pontuações

# %% [markdown]
# Stop Words são palavras consideradas de baixa relevância e normalmente são retiradas no pré-processamento, com a resalva que existem casos em que a remoção dessas palavra pioram o resultado do algoritmo utilizado.
# <br />
# O cojunto de stopword para português do spacy pode ser encontrado com o comando `spacy.lang.pt.stop_words.STOP_WORDS`

# %%
spacy_stopwords = spacy.lang.pt.stop_words.STOP_WORDS
print(f'Number of stop words: {len(spacy_stopwords)}')
print(f'First ten stop words: {list(spacy_stopwords)}')
# Out:
# Number of stop words: 413
# First ten stop words: ['atrás', 'foste', 'corrente', 'dar', 'desse', 'muitos', 'vêm', 'tudo', 'que', 'tentar', 'estar', 'fazem', 'seus', 'embora', 'ademais', 'baixo', 'novos', 'este', 'fazeis', 'dois', 'das', 'diante', 'aquilo', 'onze', 'vão', 'certamente', 'porquê', 'qualquer', 'daquela', 'além', 'querem', 'aquele', 'neste', 'apoio', 'próprio', 'tive', 'com', 'vens', 'todos', 'acerca', 'já', 'ali', 'tivestes', 'questão', 'segunda', 'algo', 'dos', 'fui', 'vossa', 'de', 'tanto', 'pois', 'quarta', 'estive', 'números', 'novo', 'pouca', 'geral', 'é', 'fará', 'minha', 'ambas', 'vezes', 'pontos', 'estiveram', 'menos', 'zero', 'último', 'quieta', 'estava', 'sexto', 'disso', 'tanta', 'te', 'sete', 'lhe', 'em', 'não', 'próxima', 'nós', 'oitavo', 'aquela', 'local', 'tentaram', 'demais', 'momento', 'eles', 'segundo', 'isto', 'vos', 'usa', 'contudo', 'doze', 'isso', 'fazia', 'lado', 'estivemos', 'fazer', 'caminho', 'dá', 'veja', 'dentro', 'boa', 'no', 'meu', 'assim', 'minhas', 'vindo', 'por', 'à', 'põe', 'num', 'tendes', 'deverá', 'sem', 'nunca', 'tua', 'iniciar', 'através', 'fora', 'nada', 'fim', 'inicio', 'fez', 'tal', 'direita', 'grupo', 'mal', 'valor', 'dizer', 'fomos', 'vinte', 'nove', 'debaixo', 'aqui', 'sim', 'eventual', 'estará', 'toda', 'desde', 'sobre', 'sistema', 'numa', 'esse', 'tentei', 'dez', 'puderam', 'usar', 'desta', 'vosso', 'duas', 'seria', 'estas', 'exemplo', 'naquela', 'tente', 'pelos', 'seu', 'mais', 'vários', 'aquelas', 'adeus', 'tivemos', 'estiveste', 'após', 'vossos', 'temos', 'longe', 'ir', 'nos', 'ou', 'onde', 'partir', 'ter', 'até', 'conselho', 'meses', 'porque', 'qual', 'sou', 'nas', 'podia', 'primeiro', 'cedo', 'fostes', 'sei', 'muito', 'ainda', 'teu', 'portanto', 'quinto', 'antes', 'outra', 'novas', 'nossos', 'catorze', 'quê', 'dessa', 'falta', 'fazes', 'oitava', 'contra', 'devem', 'maioria', 'alguns', 'és', 'quarto', 'menor', 'cento', 'põem', 'maiorias', 'apoia', 'dezasseis', 'cujo', 'poder', 'quem', 'ver', 'outros', 'somente', 'todo', 'deve', 'possivelmente', 'sétima', 'tem', 'povo', 'vocês', 'mas', 'nessa', 'três', 'agora', 'teve', 'mesmo', 'umas', 'final', 'coisa', 'ele', 'vossas', 'breve', 'ela', 'na', 'logo', 'ao', 'eu', 'posso', 'estes', 'naquele', 'tarde', 'cá', 'suas', 'bom', 'deste', 'teus', 'nuns', 'estado', 'nesta', 'para', 'treze', 'nesse', 'mil', 'nossa', 'os', 'pode', 'pelas', 'da', 'área', 'conhecido', 'nova', 'maior', 'saber', 'sob', 'ontem', 'dezassete', 'favor', 'estivestes', 'uns', 'dezanove', 'for', 'às', 'foram', 'diz', 'dizem', 'meio', 'quer', 'posição', 'ambos', 'sétimo', 'pegar', 'parte', 'têm', 'quatro', 'todas', 'conhecida', 'aí', 'certeza', 'pôde', 'forma', 'sabe', 'era', 'obrigada', 'cima', 'bem', 'ora', 'relação', 'vai', 'tiveste', 'me', 'cuja', 'quinta', 'possível', 'comprido', 'elas', 'tuas', 'quais', 'mês', 'faço', 'daquele', 'comprida', 'pelo', 'entre', 'sempre', 'perto', 'meus', 'esta', 'porém', 'seis', 'obrigado', 'próximo', 'máximo', 'inclusive', 'tempo', 'vós', 'enquanto', 'pouco', 'tu', 'grande', 'oito', 'aqueles', 'algumas', 'apontar', 'estão', 'essas', 'vez', 'vais', 'esses', 'quinze', 'um', 'número', 'sua', 'terceiro', 'ponto', 'depois', 'esteve', 'poderá', 'vinda', 'quanto', 'nossas', 'quieto', 'essa', 'bastante', 'faz', 'tipo', 'aos', 'porquanto', 'tais', 'lugar', 'ligado', 'do', 'foi', 'custa', 'dezoito', 'as', 'quero', 'estás', 'ser', 'outras', 'então', 'talvez', 'nível', 'está', 'dão', 'irá', 'lá', 'grandes', 'se', 'tens', 'tiveram', 'quando', 'você', 'cada', 'terceira', 'pela', 'vem', 'nosso', 'nem', 'sois', 'só', 'podem', 'tão', 'primeira', 'parece', 'cinco', 'como', 'uma', 'apenas', 'são', 'des', 'também', 'tenho', 'nenhuma', 'sexta', 'estou', 'fazemos', 'somos']

# %% [markdown]
# O objeto **Document** (**Doc**) é composto por uma lista de **Token**'s, para a remoção das stop words e pontuações é verificado em cada **Token** se ele é um dos casos `if not(token.is_stop or token.is_punct)`.

# %%
for sentence in sentences_example:
  doc = nlp(sentence)
  new = [token.text.lower() for token in doc if not(token.is_stop or token.is_punct)]
  print(f"Before  : {sentence}")
  print("After   : {}".format(" ".join(new)))
# Out:
# Before  : Obrigada pela homenagem ao #casamentoigualitario , @BancodoBrasil @BancoDoBrasil7  !! Vejam aqui: http://t.co/4hICRrgnrW ! Muito bom!
# After   : obrigada homenagem a o casamentoigualitario @bancodobrasil @bancodobrasil7   vejam http://t.co/4hicrrgnrw muito
# Before  : O #BancoDoBrasil já me deixou uma mensagem de parabéns. O 1º.
# After   : o bancodobrasil deixou mensagem parabéns o 1º.
# Before  : Bora ser seu próprio chefe, trabalhar com esportes e ganhar 20 mil reais? A #InterU e o @BancoDoBrasil explicam como: http://t.co/ZgbqthSluF
# After   : bora chefe esportes e ganhar 20 reais a interu e o @bancodobrasil explicam http://t.co/zgbqthsluf
# Before  : HAHAHAHA @BancodoBrasil maravilhoso!!!! http://t.co/mscHrnWiA4
# After   : hahahaha @bancodobrasil maravilhoso http://t.co/mschrnwia4
# Before  : Parabens ao @BancodoBrasil #circuitobancodobrasil por um evento desse nivel! Esse banco tem historia no esporte! http://t.co/GBHjhVCIxu
# After   : parabens a o @bancodobrasil circuitobancodobrasil evento d nivel esse banco historia esporte http://t.co/gbhjhvcixu

# %% [markdown]
# ## Radical das palavras (Lemmatization)

# %% [markdown]
# Lemmatization é o processo de romover o radical das palvras, mantendo somente a parte "raiz" (talvez raiz não seja uma boa palavra para descrever).

# %%
for sentence in sentences_example:
  doc = nlp(sentence)
  new = [token.text.lower() for token in doc if not(token.is_stop or token.is_punct)]
  lemmas = [token.lemma_.lower() for token in nlp(" ".join(new))]
  print(" ".join(lemmas))
# Out:
# obrigar homenagem o o casamentoigualitario @bancodobrasil @bancodobrasil7    ver http://t.co/4hicrrgnrw muito
# o bancodobrasil deixar mensagem parabém o 1º.
# bora chefe esportes e ganhar 20 real o interu e o @bancodobrasil explicar http://t.co/zgbqthsluf
# hahahaha @bancodobrasil maravilhoso http://t.co/mschrnwia4
# parabens o o @bancodobrasil circuitobancodobrasil evento d nivel esse banco historiar esporte http://t.co/gbhjhvcixu

# %% [markdown]
# ## POS Tagging

# %% [markdown]
# Representa a indentificação da palavra como (sujeiro, advérbio, verbo, etc).
# <br/>
# É "retornada" pelo atributo `pos_`de cada **Token**.

# %%
for sentence in sentences_example:
  doc = nlp(sentence)
  for token in doc:
    print(token.text, token.pos_)
# Out:
# Obrigada VERB
# pela DET
# homenagem NOUN
# a ADP
# o DET
# # PROPN
# casamentoigualitario ADJ
# , PUNCT
# @BancodoBrasil X
# @BancoDoBrasil7 ADJ
#   SPACE
# ! PUNCT
# ! PUNCT
# Vejam VERB
# aqui ADV
# : PUNCT
# http://t.co/4hICRrgnrW ADV
# ! PUNCT
# Muito ADV
# bom ADJ
# ! PUNCT
# O DET
# # SYM
# BancoDoBrasil PROPN
# já ADV
# me PRON
# deixou VERB
# uma DET
# mensagem NOUN
# de ADP
# parabéns NOUN
# . PUNCT
# O DET
# 1º. ADJ
# Bora ADV
# ser VERB
# seu DET
# próprio ADJ
# chefe NOUN
# , PUNCT
# trabalhar VERB
# com ADP
# esportes NOUN
# e CCONJ
# ganhar VERB
# 20 NUM
# mil NUM
# reais SYM
# ? PUNCT
# A DET
# # PROPN
# InterU PROPN
# e CCONJ
# o DET
# @BancoDoBrasil NOUN
# explicam VERB
# como ADP
# : PUNCT
# http://t.co/ZgbqthSluF NOUN
# HAHAHAHA PROPN
# @BancodoBrasil NOUN
# maravilhoso ADJ
# ! PUNCT
# ! PUNCT
# ! PUNCT
# ! PUNCT
# http://t.co/mscHrnWiA4 PROPN
# Parabens NOUN
# a ADP
# o DET
# @BancodoBrasil NOUN
# # NOUN
# circuitobancodobrasil ADJ
# por ADP
# um DET
# evento NOUN
# d ADP
# esse DET
# nivel ADJ
# ! PUNCT
# Esse DET
# banco NOUN
# tem AUX
# historia NOUN
# no PRON
# esporte NOUN
# ! PUNCT
# http://t.co/GBHjhVCIxu VERB

# %% [markdown]
# ## Entidades

# %% [markdown]
# É possível identificar entidades presentes no texto com o atributo `label_` do **Token**

# %%
for sentence in sentences_example:
  doc = nlp(sentence)
  for entity in doc.ents:
    print(entity.text,entity.label_)
# Out:
#  !! MISC
# Vejam PER
# BancoDoBrasil LOC
# InterU MISC

# %% [markdown]
# ## Fazendo na prática para os tweets

# %% [markdown]
# Agora vamos realizar alguns dos comandos acima.
# <br/>
# Uma particularidade dos textos (tweets) utilizados neste notebook é a presença de links, o padrão do tweeter é encurtar os links, uma maior explicação encontra-se em: [how-to-tweet-a-link](https://help.twitter.com/en/using-twitter/how-to-tweet-a-link). Por isso foi necessário criar uma função para indentificar os links. A função utiliza [regex](https://www.w3schools.com/python/python_regex.asp) para fazer esse trabalho.

# %%
import re

def is_link(text):
   return re.match("^http:\/\/t\.co.*", text)

# %% [markdown]
# Agora só retirar links, stop words e pontuações e obter o radical das palavras resultantes.

# %%
for full_sentence in tweets_df["text"]:
  print("[Sem alterar] -->", full_sentence)
  doc = nlp(full_sentence)
  no_stop_words = [token.text.lower() for token in doc if not(token.is_stop or token.is_punct or is_link(token.text))]
  no_stop_sentence = " ".join(no_stop_words)
  print("[Sem STOP   ] -->", no_stop_sentence)
  doc = nlp(" ".join(no_stop_words))
  lemmas = [token.lemma_.lower() for token in doc]
  lemma_sentence = " ".join(lemmas)
  print("[LEMMA      ] -->", lemma_sentence)
# Out:
# [Sem alterar] --> Obrigada pela homenagem ao #casamentoigualitario , @BancodoBrasil @BancoDoBrasil7  !! Vejam aqui: http://t.co/4hICRrgnrW ! Muito bom!
# [Sem STOP   ] --> obrigada homenagem a o casamentoigualitario @bancodobrasil @bancodobrasil7   vejam muito
# [LEMMA      ] --> obrigar homenagem o o casamentoigualitario @bancodobrasil @bancodobrasil7    ver muito
# [Sem alterar] --> O #BancoDoBrasil já me deixou uma mensagem de parabéns. O 1º.
# [Sem STOP   ] --> o bancodobrasil deixou mensagem parabéns o 1º.
# [LEMMA      ] --> o bancodobrasil deixar mensagem parabém o 1º.
# [LEMMA      ] --> @alobradesco o canal rápido respostar banco solução prometido amanhã até
# [Sem alterar] --> Hércules, Regilandio e Stefano do @AloBradesco resolveram migração para o MAC. Obrigado pelas partes envolvidas
# [Sem STOP   ] --> hércules regilandio e stefano @alobradesco resolveram migração o mac obrigado partes envolvidas
# [LEMMA      ] --> hércules regilandio e stefano @alobradesco resolver migração o mac obrigar partir envolvido
# [Sem alterar] --> #Bradesco e #Itau PARABENS pela responsabilidade social. #EuNoTeleton
# [Sem STOP   ] --> bradesco e itau parabens responsabilidade social eunoteleton
# [LEMMA      ] --> bradesco e itau parabens responsabilidade social eunoteleton
# [Sem alterar] --> #EuNoTeleton eo   @Bradesco tambem
#
#    #EuNoTeleton + Voce = Nós ..só depende de Nós
# [Sem STOP   ] --> eunoteleton eo    @bradesco tambem
#
#     eunoteleton + voce = nós só depende nós
# [LEMMA      ] --> eunoteleton eo     @bradesco tambem
#
#      eunoteleton + voce = nó só depender nó
# [Sem alterar] --> R$ 1.2 MIl! Doação do @Bradesco para o #TeletonBrasil2013.
# [Sem STOP   ] --> r$ 1.2 mil doação @bradesco o teletonbrasil2013
# [LEMMA      ] --> r$ 1.2 mil doação @bradesco o teletonbrasil2013
# [Sem alterar] --> Aew #Bradesco, R$1.200.000,00 pro #Teleton. Muito bom!
# [Sem STOP   ] --> aew bradesco r$1.200.000,00 pro teleton muito
# [LEMMA      ] --> aew bradesco r$1.200.000,00 pro teleton muito
# [Sem alterar] --> Parabens @Bradesco pela Doaçao de 1milhão e 200 mil #EUNoTeleton
# [Sem STOP   ] --> parabens @bradesco doaçao 1milhão e 200 eunoteleton
# [LEMMA      ] --> parabens @bradesco doaçao 1milhão e 200 eunoteleton
# [Sem alterar] --> Isso aí R$1.200.000,00 parabéns @Bradesco !!! @TeletonOficial
# [Sem STOP   ] --> isso r$1.200.000,00 parabéns @bradesco @teletonoficial
# [LEMMA      ] --> isso r$1.200.000,00 parabém @bradesco @teletonoficial
# [Sem alterar] --> Bradesco - O banco @Bradesco doou R$1.200.000,00 @TeletonOficial. Twitteiros parabenizam . #TudoTrendsBR
# [Sem STOP   ] --> bradesco o banco @bradesco doou r$1.200.000,00 @teletonoficial twitteiros parabenizam tudotrendsbr
# [LEMMA      ] --> bradesco o banco @bradesco doar r$1.200.000,00 @teletonoficial twitteiros parabenizar tudotrendsbr
# [Sem alterar] --> #Itaú e #Bradesco juntos por uma ótima causa.... Louvável
# [Sem STOP   ] --> itaú e bradesco juntos ótima causa louvável
# [LEMMA      ] --> itaú e bradesco junto ótima causar louvável
# [Sem alterar] --> @angelicamari @Bradesco aqui o Bradesco vai bem em chrome!
# [Sem STOP   ] --> @angelicamari @bradesco o bradesco chrome
# [LEMMA      ] --> @angelicamari @bradesco o bradesco chrome
# [Sem alterar] --> Trabalhar no #Bradesco é ter rock ao vivo! Born to be wiiiineee... :D http://t.co/iLQlUqHHw0
# [Sem STOP   ] --> trabalhar bradesco rock a o vivo born to be wiiiineee :d
# [LEMMA      ] --> trabalhar bradesco rock o o viver born to be wiiiineee : d
# [Sem alterar] --> Mais uma vez obrigado @AloBradesco pela eficiência no trato com os clientes.
# [Sem STOP   ] --> mais @alobradesco eficiência trato clientes
# [LEMMA      ] --> mais @alobradesco eficiência tratar cliente
# [Sem alterar] --> Esses dias fiz uma reclamação do #Bradesco aqui no twitter e a equipe do @AloBradesco foi bem atenciosa...
# [Sem STOP   ] --> esses dias fiz reclamação bradesco twitter e a equipe @alobradesco atenciosa
# [LEMMA      ] --> esse dia fazer reclamação bradesco twitter e o equipar @alobradesco atencioso
# [Sem alterar] --> O @Bradesco @AloBradesco me ligou e resolveu meu problema rapidinho. Valeu Bradesco!!
# [Sem STOP   ] --> o @bradesco @alobradesco ligou e resolveu problema rapidinho valeu bradesco
# [LEMMA      ] --> o @bradesco @alobradesco ligar e resolver problema rapidinho valer bradesco
# [Sem alterar] --> EU SIGO E INDICO &gt;&gt;&gt;&gt;&gt;@Bradesco
# [Sem STOP   ] --> eu sigo e indico gt;&gt;&gt;&gt;&gt;@bradesco
# [LEMMA      ] --> eu seguir e indicar gt;&gt;&gt;&gt;&gt;@bradesco
# [Sem alterar] --> Parabéns a todos que fazem os perfis @AloBradesco! #Show
# [Sem STOP   ] --> parabéns a perfis @alobradesco show
# [LEMMA      ] --> parabém o perfil @alobradesco show
# [Sem alterar] --> Atendimento do @AloBradesco sempre excelente. Token ativo sem precisar ir ao banco. Aprende com eles @HSBC_Atende.
# [Sem STOP   ] --> atendimento @alobradesco excelente token ativo precisar a o banco aprende @hsbc_atende
# [LEMMA      ] --> atendimento @alobradesco excelente token ativo precisar o o banco aprender @hsbc_atende
# [Sem alterar] --> @AloBradesco Ok muito obrigado por tirar minha duvida , estou seguindo vocês uma ótima tarde
# [Sem STOP   ] --> @alobradesco ok tirar duvida seguindo ótima
# [LEMMA      ] --> @alobradesco ok tirar duvidar seguir ótima
# [Sem alterar] --> @AloBradesco Obrigado pela atenção
# [Sem STOP   ] --> @alobradesco obrigado atenção
# [LEMMA      ] --> @alobradesco obrigar atenção
# [Sem alterar] --> Meu cartão Visa acabou de chegar, obrigada @AloBradesco &lt;3
# [Sem STOP   ] --> meu cartão visa acabou chegar @alobradesco lt;3
# [LEMMA      ] --> meu cartão visar acabar chegar @alobradesco lt;3
# [Sem alterar] --> Impressionante o poder da rede social ! O @AloBradesco funciona MUITO melhor que o fone fácil !!! Obrigado bradesco !!!
# [Sem STOP   ] --> impressionante o rede social o @alobradesco funciona muito melhor o fone fácil obrigado bradesco
# [LEMMA      ] --> impressionante o redar social o @alobradesco funcionar muito melhor o fone fácil obrigar bradesco
# [Sem alterar] --> Obrigado @AloBradesco ! TUDO resolvido em menos de 24 hs !!! Obrigado mesmo !
# [Sem STOP   ] --> obrigado @alobradesco tudo resolvido 24 hs obrigado
# [LEMMA      ] --> obrigar @alobradesco tudo resolver 24 hs obrigar
# [Sem alterar] --> Muito feliz com o @alobradesco ! Resolveram tudo pra mim !!! Ja o fone fácil , espero que caia uma bomba lá e exploda todo mundo !!!!
# [Sem STOP   ] --> brasilsemmiséria saiu graças a @caixa
# [LEMMA      ] --> brasilsemmiséria sair graça o @caixa
# [Sem alterar] --> @ClaroBrasil @ClaroRonaldo Muito obrigado !!! a promoção do twitter foi a melhor coisa que vocês poderiam inventar ...
# [Sem STOP   ] --> @clarobrasil @claroronaldo muito a promoção twitter a melhor poderiam inventar
# [LEMMA      ] --> @clarobrasil @claroronaldo muito o promoção twitter o melhor poder inventar
# [Sem alterar] --> Mas um dia de trabalho !!! ?????? #bomdia #trabalho #mywork #work #clarobrasil #mylife #lifeisbutadream… http://t.co/TGBNg1SZhu
# [Sem STOP   ] --> mas bomdia mywork work clarobrasil mylife lifeisbutadream
# [LEMMA      ] --> mas bomdia mywork work clarobrasil mylife lifeisbutadream
# [Sem alterar] --> FINALMENTE CONSEGUI A PORTABILIDADE - QUASE SEM ESFORÇO. OBRIGADO, @ClaroBlog! &lt;3 &lt;3 &lt;3 http://t.co/gMtjTMezlF
# [Sem STOP   ] --> finalmente consegui a portabilidade quase sem esforço obrigado @claroblog lt;3 lt;3 lt;3
# [LEMMA      ] --> finalmente conseguir o portabilidade quase sem esforçar obrigar @claroblog lt;3 lt;3 lt;3
# [Sem alterar] --> Novo dia, Novas metas, novos desafios... Hora de Produzir!!! ???????????? #bomdia #mywork #clarobrasil… http://t.co/vVwk8hhv65
# [Sem STOP   ] --> novo novas metas desafios hora produzir bomdia mywork clarobrasil
# [LEMMA      ] --> novo novo meter desafio horar produzir bomdia mywork clarobrasil
# [Sem alterar] --> Bom dia Hoje é dia de Ação Externa!!! Simbora produzir... ?????????????????? #bomdia #clarobrasil #vempraclaro… http://t.co/nQ9Ddf0XxA
# [Sem STOP   ] --> bom hoje ação externa simbora produzir bomdia clarobrasil vempraclaro
# [LEMMA      ] --> bom hoje ação externo simbora produzir bomdia clarobrasil vempraclaro
# [Sem alterar] --> Ação Externa !!! ????????????? #clarobrasil #sejoga #vempraclaro #trabalho #mywork #love #equipeplanet… http://t.co/E5Zbv1jAYV
# [Sem STOP   ] --> ação externa clarobrasil sejoga vempraclaro mywork love equipeplanet
# [LEMMA      ] --> ação externo clarobrasil sejoga vempraclaro mywork love equipeplanet
# [Sem alterar] --> obgrigada @claro pelo tt mobile de graça \o/
# [Sem STOP   ] --> obgrigada @claro tt mobile graça \o/
# [LEMMA      ] --> obgrigada @claro t mobilar graça \o/
# [Sem alterar] --> Muito obrigado @ClaroBlog pelo presente de 200 torpedos
# [Sem STOP   ] --> muito @claroblog presente 200 torpedos
# [LEMMA      ] --> muito @claroblog presentar 200 torpedo
# [Sem alterar] --> @ClaroBlog Sou cliente da Claro a 6 anos e meio e nunca tive sérios problemas, ja em uma concorrente foram 3 meses de tortura!
# [Sem STOP   ] --> @claroblog sou cliente claro a 6 e e sérios problemas ja concorrente 3 tortura
# [LEMMA      ] --> @claroblog ser cliente claro o 6 e e sério problema ja concorrente 3 torturar
# [Sem alterar] --> Opa, curti, parece que acesso ao facebook pela claro está de grátis. #ClaroBrasil #ClaroRonaldo #Chupa3g  @claroronaldo @ClaroBrasil
# [Sem STOP   ] --> opa curti acesso a o facebook claro grátis clarobrasil claroronaldo chupa3 g   @claroronaldo @clarobrasil
# [LEMMA      ] --> opar curtir acesso o o facebook claro grátis clarobrasil claroronaldo chupa3 g    @claroronaldo @clarobrasil
# [Sem alterar] --> É por isso que as vezes eu gosto da #Claro! http://t.co/uTI4cqvriq
# [Sem STOP   ] --> é gosto claro
# [LEMMA      ] --> ser gostar claro
# [Sem alterar] --> Jênia @ClaroBrasil
# [Sem STOP   ] --> jênia @clarobrasil
# [LEMMA      ] --> jênia @clarobrasil
# [Sem alterar] --> Facebook e Twitter grátis até pra pós pago! Hehe! Aí sim @ClaroBlog
# [Sem STOP   ] --> facebook e twitter grátis pra pós pago hehe aí @claroblog
# [LEMMA      ] --> facebook e twitter grátis pra pó pagar hehe aí @claroblog
# [Sem alterar] --> Obrigada @claro
# [Sem STOP   ] --> obrigada @claro
# [LEMMA      ] --> obrigar @claro
# [Sem alterar] --> Problema resolvido, obrigada @ClaroBrasil  o/ já posso respirar melhor agora kkkk
# [Sem STOP   ] --> problema resolvido @clarobrasil   o/ respirar melhor kkkk
# [LEMMA      ] --> problema resolver @clarobrasil    o/ respirar melhor kkkk
# [Sem alterar] --> Essa 3G da @claro é uma beleza.
# [Sem STOP   ] --> essa 3 g @claro beleza
# [LEMMA      ] --> esse 3 g @claro beleza
# [Sem alterar] --> Hoje é dia de ser Feliz... ????????????? #bomdia #trabalho #clarobrasil #foco #força #fe… http://t.co/BE8YalDtMl
# [Sem STOP   ] --> hoje feliz bomdia clarobrasil foco força fe
# [LEMMA      ] --> hoje feliz bomdia clarobrasil focar forçar fe
# [Sem alterar] --> E a #Claro (@ClaroRonaldo) dando show de respeito ao cliente! Parabéns!!
# http://t.co/JgsuexDo81
# [Sem STOP   ] --> e a claro @claroronaldo dando show respeito a o cliente parabéns
#
# [LEMMA      ] --> e o claro @claroronaldo dar show respeitar o o cliente parabém
#
# [Sem alterar] --> Obrigado, @claroronaldo @clarobrasil, finalmente eu consegui fazer meu modem funcionar depois de UM ANO usando a @timbrasil.
# [Sem STOP   ] --> obrigado @claroronaldo @clarobrasil finalmente consegui modem funcionar um ano usando a @timbrasil
# [LEMMA      ] --> obrigar @claroronaldo @clarobrasil finalmente conseguir modem funcionar um ano usar o @timbrasil
# [Sem alterar] --> Gente eu aqui passado com a velocidade do 4G do iPhone 5S da #Claro (Perfeito)
# [Sem STOP   ] --> gente passado a velocidade 4 g iphone 5s claro perfeito
# [LEMMA      ] --> gente passar o velocidade 4 g iphone 5s claro perfazer
# [Sem alterar] --> @Gusbelli @claro eu uso e não tenho problemas aqui no Rio.
# [Sem STOP   ] --> @gusbelli @claro uso e problemas rio
# [LEMMA      ] --> @gusbelli @claro usar e problema rir
# [Sem alterar] --> @danicarolp @claro eles estão com um pacotes combos com a @NEToficial que parecem interessantes
# [Sem STOP   ] --> @danicarolp @claro pacotes combos a @netoficial parecem interessantes
# [LEMMA      ] --> @danicarolp @claro pacote combos o @netoficial parecer interessante
# [Sem alterar] --> obrigado…mas poxa… RT @ClaroBlog: Olá, Neto. Pode ficar tranquilo que o acesso será liberado em dezembro. Conte com a gente se precisar.
# [Sem STOP   ] --> poxa rt @claroblog olá neto pode ficar tranquilo o acesso será liberado dezembro conte a gente precisar
# [LEMMA      ] --> poxa rt @claroblog olá neto poder ficar tranquilo o acesso ser liberar dezembro contar o gente precisar
# [Sem alterar] --> A Internet 4G da #Claro é outro nível hein !!!! Luxo, Poder e Glória !!!
# [Sem STOP   ] --> a internet 4 g claro hein luxo poder e glória
# [LEMMA      ] --> o internet 4 g claro hein luxar poder e glória
# [Sem alterar] --> @ClaroBlog Enfim, como vcs já me ajudaram... conto com vcs mais uma vez...
# [Sem STOP   ] --> @claroblog enfim vcs ajudaram conto vcs
# [LEMMA      ] --> @claroblog enfim vcs ajudar contar vcs
# [Sem alterar] --> Confraternização da clarobrasil .Amo muito tudo isso ????????? #confraternizacao #clarobrasil… http://t.co/tvPQLxtdJq
# [Sem STOP   ] --> confraternização clarobrasil .amo confraternizacao clarobrasil
# [LEMMA      ] --> confraternização clarobrasil .amo confraternizacao clarobrasil
# [Sem alterar] --> É Claro que é a melhor Equipe !!! ?????????? #clarobrasil #equipeplanet #trabalho #mywork… http://t.co/FsDSkDuwvr
# [Sem STOP   ] --> é claro a melhor equipe clarobrasil equipeplanet mywork
# [LEMMA      ] --> ser claro o melhor equipar clarobrasil equipeplanet mywork
# [Sem alterar] --> Equipe Claro @planetcellcg
# Equipe Bombacao !!! ????????????? #clarobrasil #equipeplanet #equipebombacao… http://t.co/Br4rLSsn3D
# [Sem STOP   ] --> equipe claro @planetcellcg
#  equipe bombacao clarobrasil equipeplanet equipebombacao
# [LEMMA      ] --> equipar claro @planetcellcg
#   equipar bombacao clarobrasil equipeplanet equipebombacao
# [Sem alterar] --> demorou, mas enfim a dona @ClaroBrasil resolveu atender minha solicitação...
# [Sem STOP   ] --> demorou enfim a dona @clarobrasil resolveu atender solicitação
# [LEMMA      ] --> demorar enfim o dono @clarobrasil resolver atender solicitação
# [Sem alterar] --> E viva o #4GMax da #Claro!!! \0/ http://t.co/hWakXeTpNl
# [Sem STOP   ] --> e viva o 4gmax claro \0/
# [LEMMA      ] --> e vivo o 4gmax claro \0/
# [Sem alterar] --> como presente de natal a minha 3g está muito rápida obg @vivo
# [Sem STOP   ] --> presente natal a 3 g rápida obg @vivo
# [LEMMA      ] --> presentar natal o 3 g rápido obg @vivo
# [Sem alterar] --> 4G da @ClaroBlog até agora funcionando muito bem.
# [Sem STOP   ] --> 4 g @claroblog funcionando
# [LEMMA      ] --> 4 g @claroblog funcionar
# [Sem alterar] --> @NFumache @ClaroBlog o 3G comigo sempre funciona muito bem também rsrsrs
# [Sem STOP   ] --> @nfumache @claroblog o 3 g comigo funciona rsrsrs
# [LEMMA      ] --> @nfumache @claroblog o 3 g comigo funcionar rsrsrs
# [Sem alterar] --> "Eu faço parte de algo que é capaz de fazer sorrir, encantar, alegrar e emocionar.
# [Sem alterar] --> leia para uma criança #itau http://t.co/Mv73Idhwvv
# [Sem STOP   ] --> leia criança itau
# [LEMMA      ] --> ler criança itau
# [Sem alterar] --> #Bradesco e #Itau PARABENS pela responsabilidade social. #EuNoTeleton
# [Sem STOP   ] --> bradesco e itau parabens responsabilidade social eunoteleton
# [LEMMA      ] --> bradesco e itau parabens responsabilidade social eunoteleton
# [Sem alterar] --> #Itaú e #Bradesco juntos por uma ótima causa.... Louvável
# [Sem STOP   ] --> itaú e bradesco juntos ótima causa louvável
# [LEMMA      ] --> itaú e bradesco junto ótima causar louvável
# [Sem alterar] --> Sempre MUITO bem atendida pela @Itaucard ! Muito obrigada!
# [Sem STOP   ] --> sempre muito atendida @itaucard muito
# [LEMMA      ] --> sempre muito atendido @itaucard muito
# [Sem alterar] --> #LeiaParaUmaCriança #IssoMudaOMundo #Itaú http://t.co/wvZ6u8lsN5
# [Sem STOP   ] --> leiaparaumacriança issomudaomundo itaú
# [LEMMA      ] --> leiaparaumacriança issomudaomundo itaú
# [Sem alterar] --> opaa problema solucionado! #ItauCard lindo rsrs 'não mostre o seu #CartãoCrédito a ninguém =)
# [Sem STOP   ] --> opaa problema solucionado itaucard lindo rsrs mostre o cartãocrédito a ninguém =)
# [LEMMA      ] --> opaa problema solucionar itaucard lindar rsrs mostrar o cartãocrédito o ninguém =)
# [Sem alterar] --> Chegaram! Obrigada #itau http://t.co/h1Rp2Gn0eZ
# [Sem STOP   ] --> chegaram obrigada itau
# [LEMMA      ] --> chegar obrigar itau
# [Sem alterar] --> @Itaucard obrigado pelo atendimento rápido e pela solução do ocorrido. (Y)
# [Sem STOP   ] --> @itaucard atendimento rápido e solução ocorrido y
# [LEMMA      ] --> @itaucard atendimento rápido e solução ocorrer y
# [Sem alterar] --> @Animadissima Bom dia! Em casos relacionados ao cartão peço que entre em contato com o @itaucard, eles irão te ajudar da melhor forma. =)
# [Sem STOP   ] --> @animadissima bom em casos relacionados a o cartão peço contato o @itaucard irão ajudar melhor =)
# [LEMMA      ] --> @animadissima bom em caso relacionar o o cartão pedir contato o @itaucard ir ajudar melhor =)
# [Sem alterar] --> Consegui estornar uma compra indevida feita no ML com meu cartão de crédito em 5 minutos! Parabéns Itaucard pela eficiência #itaucard #itau
# [Sem STOP   ] --> consegui estornar compra indevida feita ml cartão crédito 5 minutos parabéns itaucard eficiência itaucard itau
# [LEMMA      ] --> conseguir estornar comprar indevido feito ml cartão crédito 5 minuto parabém itaucard eficiência itaucard itau
# [Sem alterar] --> @Itaucard Obrigado por responder tão rápido ;-)
# [Sem STOP   ] --> @itaucard obrigado responder rápido
# [LEMMA      ] --> @itaucard obrigar responder rápido
# [Sem alterar] --> @itau to TÃO feliz que nem sei explicar pra vocês. cc @Itaucard
# [Sem STOP   ] --> @itau to tão feliz explicar pra cc @itaucard
# [LEMMA      ] --> @itau to tão feliz explicar pra c @itaucard
# [Sem alterar] --> Que demora para o #Santander aprovar um compra online, se fosse #Itaucard era em minutos... #tenso
# [Sem STOP   ] --> que demora o santander aprovar compra online fosse itaucard minutos tenso
# [Sem STOP   ] --> menus sky atualizados ficou top skybrasil
# [LEMMA      ] --> menu sky atualizados ficar top skybrasil
# [Sem alterar] --> Tenhos Net e Sky já! RT @Chico_PC: @edutrevisan @SKYresponde muda pra @NEToficial quem tem 3 ESPNs EM HD!! + 2 SPORTVs e a FOXSPORTS!
# [Sem STOP   ] --> tenhos net e sky rt @chico_pc @edutrevisan @skyresponde muda pra @netoficial 3 espns em hd + 2 sportvs e a foxsports
# [LEMMA      ] --> tenhos net e sky rt @chico_pc @edutrevisan @skyresponde mudo pra @netoficial 3 espns em hd + 2 sportvs e o foxsports
# [Sem alterar] --> @SKYresponde Curti a nova cara da #SkyHDTV Parabens...
# [Sem STOP   ] --> @skyresponde curti a cara skyhdtv parabens
# [LEMMA      ] --> @skyresponde curtir o caro skyhdtv parabens
# [Sem alterar] --> @skybrasil  atualização de ontem fico muito bom novo menu #skybrasil #sky #novasky http://t.co/N1DMBAEm1n
# [Sem STOP   ] --> @skybrasil   atualização fico menu skybrasil sky novasky
# [LEMMA      ] --> @skybrasil    atualização ficar menu skybrasil sky novasky
# [Sem alterar] --> muito melhor e bonito o novo guia de programação da @skybrasil! Quando é pra elogiar, vamos elogiar. #SKYbrasil
# [Sem STOP   ] --> melhor e bonito o guia programação @skybrasil quando pra elogiar vamos elogiar skybrasil
# [LEMMA      ] --> melhor e bonito o guiar programação @skybrasil quando pra elogiar ir elogiar skybrasil
# [Sem alterar] --> Amei em estar com o meu time @Skybrasil  vcs são demais todos vcs.
#  I love this time that I had… http://t.co/ZfZoTsQNx1
# [Sem STOP   ] --> amei o time @skybrasil   vcs vcs
#   i love this time that i had
# [LEMMA      ] --> amar o time @skybrasil    vcs vcs
#    ir love this time that ir had
# [Sem alterar] --> Achei muito top o novo design da SKY HD (y)
#
# #SkyBrasil #SkyHD #NovoDesign
# [Sem STOP   ] --> achei top o design sky hd y
#
#  skybrasil skyhd novodesign
# [LEMMA      ] --> achar top o design sky hd y
#
#   skybrasil skyhd novodesign
# [Sem alterar] --> Sinal perfeito com chuva forte, mais um mito derrubado!! #Sky #skybrasil #chuva #rain #hdtvéisso #dth… http://t.co/BYnsmtFP4l
# [Sem STOP   ] --> sinal perfeito chuva forte mito derrubado sky skybrasil chuva rain hdtvéisso dth
# [LEMMA      ] --> sinal perfazer chuva forte mito derrubar sky skybrasil chuva rain hdtvéisso dth
# [Sem alterar] --> Marcela Temer acaba de me ligar e informar que a @skybrasil resolveu o problema lá de casa. Finalmente! Poderei ver o Galo em HD no Mundial!
# [Sem STOP   ] --> marcela temer acaba ligar e informar a @skybrasil resolveu o problema casa finalmente poderei o galo hd mundial
# [LEMMA      ] --> marcela temer acabar ligar e informar o @skybrasil resolver o problema casar finalmente poder o galar hd mundial
# [Sem alterar] --> só de boa assistindo tele cineeee!
# só filme boooom!
# #skybrasil
# #telecine
# [Sem STOP   ] --> só assistindo tele cineeee
#  só filme boooom
#  skybrasil
#  telecine
# [LEMMA      ] --> só assistir tele cineeee
#   só filmar boooom
#   skybrasil
#   telecine
# [Sem alterar] --> Falei com a @SKYresponde num dia, me ligaram no outro e já tem um cara aqui pra instalar. Ótimo atendimento!
# [Sem STOP   ] --> falei a @skyresponde ligaram e cara pra instalar ótimo atendimento
# [LEMMA      ] --> falar o @skyresponde ligar e caro pra instalar ótimo atendimento
# [Sem alterar] --> Urrul! Legal esse site, tweeta automatico e rapidinho!! http://t.co/JlrM7v4E8G #timbeta #rt #socialup #legal #Oi
# [Sem STOP   ] --> urrul legal site tweeta automatico e rapidinho timbeta rt socialup legal oi
# [LEMMA      ] --> urrul legal site tweeta automatico e rapidinho timbeta rt socialup legal oi
# [Sem alterar] --> @jermbebado merece, por ter me proporcionado um plano vantajoso para q eu me comunicasse com meus amigos virtuais. Parabéns @tim
# [Sem STOP   ] --> @jermbebado merece proporcionado plano vantajoso q comunicasse amigos virtuais parabéns @tim
# [LEMMA      ] --> @jermbebado merecer proporcionar planar vantajoso q comunicar amigo virtual parabém @tim
# [Sem alterar] --> @jermbebado a @tim eh uma boa compaheiraaaa ngm pode negar
# [Sem STOP   ] --> @jermbebado a @tim eh compaheiraaaa ngm negar
# [LEMMA      ] --> @jermbebado o @tim eh compaheiraaaa ngm negar
# [Sem alterar] --> Ainda bem que o cel. é dual... a #Claro patina e não vai. Salva pela #Tim.
# [Sem STOP   ] --> ainda o cel dual a claro patina e salva tim
# [LEMMA      ] --> ainda o cel dual o claro patinar e salvo tim
# [Sem alterar] --> Adoooooooooro este casal da #vivo ele já era demais agora com ela então, gata, linda e boa atriz http://t.co/ZhD9fgPj0g
# [Sem STOP   ] --> adoooooooooro casal vivo gata linda e atriz
# [LEMMA      ] --> adoooooooooro casal viver gato lindo e atriz
# [Sem alterar] --> que deus te de em dobro, toda a velocidade de internet q vc me deu @vivo
# [Sem STOP   ] --> deus dobro a velocidade internet q vc deu @vivo
# [LEMMA      ] --> deus dobrar o velocidade internet q vc dar @vivo
# [Sem alterar] --> O atendimento do call center do Alisyon foi sensacional #Vivoemrede
# [Sem STOP   ] --> o atendimento call center alisyon sensacional vivoemrede
# [LEMMA      ] --> o atendimento call center alisyon sensacional vivoemrede
# [Sem alterar] --> #KCAArgentina #ComunidadTkm #Vivo @RadioTKM
# [Sem STOP   ] --> kcaargentina comunidadtkm vivo @radiotkm
# [LEMMA      ] --> kcaargentina comunidadtkm viver @radiotkm
# [Sem alterar] --> Minha Internet Box 4G já voltou de Jaconé !!!! #Adoro #Vivo
# [Sem STOP   ] --> minha internet box 4 g voltou jaconé adoro vivo
# [LEMMA      ] --> meu internet box 4 g voltar jaconé adorar viver
# [Sem alterar] --> #vivo, estou impressionado, hj fui atendido com rapidez pelo Guilherme que estava muito bem informado de tudo... # parabéns #momentosraros
# [Sem STOP   ] --> vivo impressionado hj atendido rapidez guilherme informado parabéns momentosraros
# [LEMMA      ] --> viver impressionar hj atender rapidez guilherme informar parabém momentosraros
# [Sem alterar] --> To na loja da @vivo comprando um "BoxVivo". Negócio tá vendendo como água.
# [Sem STOP   ] --> to loja @vivo comprando boxvivo negócio tá vendendo água
# [LEMMA      ] --> to loja @vivo comprar boxvivo negócio tá vender água
# [Sem alterar] --> ~ Acho ridículo o #BancodoBrasil estar em greve ¬¬
# [Sem STOP   ] --> ~ acho ridículo o bancodobrasil greve ¬¬
# [LEMMA      ] --> ~ achar ridículo o bancodobrasil greve ¬¬
# [Sem alterar] --> Aproveitando as cornetadas. Fujam do @BancodoBrasil
# [Sem STOP   ] --> aproveitando cornetadas fujam @bancodobrasil
# [LEMMA      ] --> aproveitar cornetada fugir @bancodobrasil
# [Sem alterar] --> Estressada com esse #BancoDoBrasil
# [Sem STOP   ] --> estressada bancodobrasil
# [LEMMA      ] --> estressada bancodobrasil
# [Sem alterar] --> Que LIXO o atendimento do @BancodoBrasil fiquei duas vezes por uns 15 ou 20 minutos aguardando atendimento, e NADA. Que lixo hein @BB
# [Sem STOP   ] --> que lixo o atendimento @bancodobrasil fiquei 15 20 minutos aguardando atendimento e nada que lixo hein @bb
# [LEMMA      ] --> que lixar o atendimento @bancodobrasil ficar 15 20 minuto aguardar atendimento e nado que lixar hein @bb
# [Sem alterar] --> não há coisa q eu odeie mais que banco. o dinheiro é meu e eu nao posso pagar a minha conta pq o @BB acha que é alto o valor..pode?
# [Sem STOP   ] --> q odeie banco o dinheiro e nao pagar a conta pq o @bb acha alto o
# [LEMMA      ] --> q odiar banco o dinheiro e nao pagar o contar pq o @bb achar alto o
# [Sem alterar] --> E o #bancodobrasil continua sem envelopes p/ depósito. #palhaçada
# [Sem STOP   ] --> e o bancodobrasil continua envelopes p/ depósito palhaçada
# [LEMMA      ] --> e o bancodobrasil continuar envelope p/ depósito palhaçada
# [Sem alterar] --> Você dá um BACK, o site desloga a sua conta, desliga o seu computador, volta no tempo e mata seus pais. ô louco, @BancodoBrasil
# [Sem STOP   ] --> você back o site desloga a conta desliga o computador volta e mata pais ô louco @bancodobrasil
# [LEMMA      ] --> você back o site desloga o contar desligar o computador voltar e matar pai ô louco @bancodobrasil
# [Sem alterar] --> Chega à redação do @PortalNoArBR notícia de confusão em agência do #BancodoBrasil Clientes revoltados, perdendo a paciência em fila enorme.
# [Sem STOP   ] --> chega redação @portalnoarbr notícia confusão agência bancodobrasil clientes revoltados perdendo a paciência fila enorme
# [LEMMA      ] --> chegar redação @portalnoarbr notícia confusão agência bancodobrasil cliente revoltar perder o paciência filar enorme
# [Sem alterar] --> Vou trocar de banco, sair do @BancodoBrasil  ir pro @itau ! Ta Osso
# [Sem STOP   ] --> vou trocar banco sair @bancodobrasil   pro @itau ta osso
# [LEMMA      ] --> ir trocar banco sair @bancodobrasil    pro @itau ta osso
# [Sem alterar] --> ...ter coisa que só se resolve na "sua agência". Burocracia pura! #BancodoBrasil #BB #satanas
# [Sem STOP   ] --> só resolve agência burocracia pura bancodobrasil bb satanas
# [LEMMA      ] --> só resolver agência burocracia puro bancodobrasil b satanas
# [Sem alterar] --> #Partiu #Fila #BancoDoBrasil #WestShopping ;*
# [Sem STOP   ] --> partiu fila bancodobrasil westshopping
# [Sem alterar] --> Árvore de Natal da #Bradesco Seguros inaugura hoje.   http://t.co/86YFWogQdu
# [Sem STOP   ] --> árvore natal bradesco seguros inaugura
# [LEMMA      ] --> árvore natal bradesco seguro inaugurar
# [Sem alterar] --> Árvore de Natal da #Bradesco Seguros inaugura hoje. http://t.co/vSkU3I08dZ
# [Sem STOP   ] --> árvore natal bradesco seguros inaugura
# [LEMMA      ] --> árvore natal bradesco seguro inaugurar
# [Sem alterar] --> #BoaTarde #Sol #Domingo #Almoço #DiasDavila #Bradesco http://t.co/Wjq8zsbG4a
# [Sem STOP   ] --> boatarde sol domingo almoço diasdavila bradesco
# [LEMMA      ] --> boatarde sol domingo almoçar diasdavila bradesco
# [Sem alterar] --> @fabiaof1 \o/ #vaiLanús!
# [Sem STOP   ] --> @fabiaof1 \o/ vailanús
# [LEMMA      ] --> @fabiaof1 \o/ vailanús
# [Sem alterar] --> Saiu de casa e esqueceu o cartão? Sem problemas! C/ a Biometria vc pode sacar usando a palma da mão! :D
# [Sem STOP   ] --> saiu casa e esqueceu o cartão sem problemas c/ a biometria vc sacar usando a palma mão :d
# [LEMMA      ] --> sair casar e esquecer o cartão sem problema c/ o biometria vc sacar usar o palmar mão : d
# [Sem alterar] --> @isabakir Bom dia! O que aconteceu?
# [Sem STOP   ] --> @isabakir bom o aconteceu
# [LEMMA      ] --> @isabakir bom o acontecer
# [Sem alterar] --> #Bradesco Seguros inaugura o Ciclo Sampa. http://t.co/BFupxbG6yp
# [Sem STOP   ] --> bradesco seguros inaugura o ciclo sampa
# [LEMMA      ] --> bradesco seguro inaugurar o ciclo sampa
# [Sem alterar] --> Bradesco Seguros estimula vida saudável com serviço de aluguel de bikes em São Paulo. (http://t.co/P2C4x6h8y2)  #bradesco #bicicletas...
# [Sem STOP   ] --> bradesco seguros estimula vida saudável serviço aluguel bikes são paulo   bradesco bicicletas
# [LEMMA      ] --> bradesco seguro estimular vidar saudável serviço aluguel bikes ser paulo    bradesco bicicleta
# [Sem alterar] --> #Bradesco Seguros inaugura o Ciclo Sampa. http://t.co/IvvQPJbW02
# [Sem STOP   ] --> bradesco seguros inaugura o ciclo sampa
# [LEMMA      ] --> bradesco seguro inaugurar o ciclo sampa
# [Sem alterar] --> @aloPSeca @LeiSecaRJ @AloBradesco @FabiGomesRJ @FEBRABAN @GovRJ Meu comprovante esta guardado....O @SacSantander_br FAZ PROPAGANDA ENGANOSA
# [Sem STOP   ] --> @alopseca @leisecarj @alobradesco @fabigomesrj @febraban @govrj meu comprovante guardado o @sacsantander_br faz propaganda enganosa
# [LEMMA      ] --> @alopseca @leisecarj @alobradesco @fabigomesrj @febraban @govrj meu comprovante guardar o @sacsantander_br fazer propaganda enganoso
# [Sem alterar] --> #Bradesco Seguros inaugura o Ciclo Sampa. http://t.co/NyBqh7ElML
# [Sem STOP   ] --> bradesco seguros inaugura o ciclo sampa
# [LEMMA      ] --> bradesco seguro inaugurar o ciclo sampa
# [Sem alterar] --> Em 2014 queremos que todo mundo tenha o que quiser! O que vc mais quer para 2014? #QueroQueTodoMundoTenha http://t.co/zUZU0294mQ
# [Sem STOP   ] --> em 2014 queremos mundo tenha o quiser o vc 2014 queroquetodomundotenha
# [LEMMA      ] --> em 2014 querer mundo ter o querer o vc 2014 queroquetodomundotenha
# [Sem alterar] --> #Bradesco Seguros inaugura o Ciclo Sampa. http://t.co/DNglnYSftL
# [Sem STOP   ] --> bradesco seguros inaugura o ciclo sampa
# [LEMMA      ] --> bradesco seguro inaugurar o ciclo sampa
# [Sem alterar] --> #QueroQueTodoMundoTenha dentes que não sujam http://t.co/4K3HG6kIc9 https://t.co/5wlkdxAyW8
# [Sem STOP   ] --> queroquetodomundotenha dentes sujam https://t.co/5wlkdxayw8
# [LEMMA      ] --> queroquetodomundotenha dente sujar https://t.co/5wlkdxayw8
# [Sem alterar] --> O novo Guia de Aparelhos da #TIM mostra de um jeito simples e fácil todas as funcionalidades do seu celular. Acesse: http://t.co/A6mRlJc7JT
# [Sem STOP   ] --> o guia aparelhos tim mostra jeito simples e fácil funcionalidades celular acesse
# [LEMMA      ] --> o guiar aparelho tim mostrar jeito simples e fácil funcionalidade celular acesse
# [Sem alterar] --> Herdeira do @Bradesco sofre nova derrota em processo bilionário contra o banco http://t.co/gU0exhcIAd
# [Sem STOP   ] --> herdeira @bradesco sofre derrota processo bilionário o banco
# [LEMMA      ] --> herdeiro @bradesco sofrer derrotar processar bilionário o banco

# %% [markdown]
# #Aplicando Inteligência Artificial  (IA) com Sklearn

# %% [markdown]
# Com o texto pré-processado pelo **Spacy**, agora vamos prepará-lo para inserir em um modelo de **IA**.

# %% [markdown]
# ##Imports

# %% [markdown]
# Como o foco deste notebook não é sobre modelos de **IA** então não faremos uma análise muito profunda nesta parte.
# <br/>
# Para esta estapa vamos usar a biblioteca **Sklearn**, com ela seremos capazes de gerar o modelo [Bag-of-words](https://en.wikipedia.org/wiki/Bag-of-words_model)  e, a partir dele, aplicaremos os algoritmos de aprendizado. Para avaliar o resultado verificaremos a qualidade do código com a medida de acurácia
# e matriz de confusão.

# %%
#tweets_df
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ##Limpesa do texto

# %%
def clear_sentence(sentence):
  doc = nlp(sentence)
  no_stop_words = [token.text.lower() for token in doc if not(token.is_stop or token.is_punct or is_link(token.text))]
  no_stop_sentence = " ".join(no_stop_words)
  doc = nlp(" ".join(no_stop_words))
  lemmas = [token.lemma_.lower() for token in doc]
  lemma_sentence = " ".join(lemmas)
  return lemma_sentence

cleared_sentences = [clear_sentence(sentence) for sentence in tweets_df["text"]]

cleared_sentences[:5]
# Out:
# ['obrigar homenagem o o casamentoigualitario @bancodobrasil @bancodobrasil7    ver muito',
#  'o bancodobrasil deixar mensagem parabém o 1º.',
#  'bora chefe esportes e ganhar 20 real o interu e o @bancodobrasil explicar',
#  'hahahaha @bancodobrasil maravilhoso',
#  'parabens o o @bancodobrasil circuitobancodobrasil evento d nivel esse banco historiar esporte']

# %% [markdown]
# ##Inicialização dos modelos e Bag Of Words

# %% [markdown]
# O modelo é gerado utilizando o `CountVectorizer` com o comando `fit_transform()` uma matriz esparsa é retornada, mas para inserir nos algoritmos é necessário utilizar o comando `toarray()` para construir a matriz densa que é necessária.

# %%
dtree = DecisionTreeClassifier(random_state=1)
rforest = RandomForestClassifier(random_state=1)
gnb = GaussianNB()
bnb = BernoulliNB()
c_vec = CountVectorizer()
kf = KFold(n_splits=4, random_state=1)
kfs = StratifiedKFold(n_splits=4, shuffle=True, random_state=1)

X = c_vec.fit_transform(cleared_sentences)
X = X.toarray()
y = tweets_df["sentiment"]

# %% [markdown]
# ##Aplicando modelos com KFolds

# %% [markdown]
# [KFold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html)

# %%
def run_model(model, X_train, X_teste, y_train, y_test):
  model.fit(X_train, y_train)
  y_predicted = model.predict(X_teste)
  accuracy = accuracy_score(y_test, y_predicted)
  return y_predicted, accuracy

# %%
kf.get_n_splits(X)

count_g = 0
count_b = 0
count_dtree = 0
count_rforest = 0

for train_index, test_index in kf.split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]
  
  predicted_gnb, accuracy_gnb = run_model(gnb, X_train, X_test, y_train, y_test)
  predicted_bnb, accuracy_bnb = run_model(bnb, X_train, X_test, y_train, y_test)
  predicted_dtree, accuracy_dtree = run_model(dtree, X_train, X_test, y_train, y_test)
  predicted_rforest, accuracy_rforest = run_model(rforest, X_train, X_test, y_train, y_test)
  
  print(f'accuracy gnb     : {accuracy_gnb}')
  print(f'accuracy bnb     : {accuracy_bnb}')
  print(f'accuracy dtree   : {accuracy_dtree}')
  print(f'accuracy rforest : {accuracy_rforest}')
  
  #print(f'confusion matrix bnb:\n{confusion_matrix(y_test, predicted_bnb, labels=["Positivo", "Negativo", "Neutro", "Irrelevante"])}')
  
  count_g += accuracy_gnb
  count_b += accuracy_bnb
  count_dtree += accuracy_dtree
  count_rforest += accuracy_rforest

print(f'erro medio gnb     : {count_g / 4}')
print(f'erro medio bnb     : {count_b / 4}')
print(f'erro medio dtree   : {count_dtree / 4}')
print(f'erro medio rforest : {count_rforest / 4}')
# Out:
# accuracy gnb     : 0.0
# accuracy bnb     : 0.0
# accuracy dtree   : 0.0
# accuracy rforest : 0.0
# accuracy gnb     : 0.0
# accuracy bnb     : 0.0
# accuracy dtree   : 0.0
# accuracy rforest : 0.0
# accuracy gnb     : 0.0
# accuracy bnb     : 0.0
# accuracy dtree   : 0.0
# accuracy rforest : 0.0
# accuracy gnb     : 0.0
# accuracy bnb     : 0.0
# accuracy dtree   : 0.0
# accuracy rforest : 0.0
# erro medio gnb     : 0.0
# erro medio bnb     : 0.0
# erro medio dtree   : 0.0
# erro medio rforest : 0.0

# %%
kfs.get_n_splits(X, y)

count_g = 0
count_b = 0
count_dtree = 0
count_rforest = 0

for train_index, test_index in kfs.split(X, y):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]
  
  predicted_gnb, accuracy_gnb = run_model(gnb, X_train, X_test, y_train, y_test)
  predicted_bnb, accuracy_bnb = run_model(bnb, X_train, X_test, y_train, y_test)
  predicted_dtree, accuracy_dtree = run_model(dtree, X_train, X_test, y_train, y_test)
  predicted_rforest, accuracy_rforest = run_model(rforest, X_train, X_test, y_train, y_test)
  
  print(f'accuracy gnb     : {accuracy_gnb}')
  print(f'accuracy bnb     : {accuracy_bnb}')
  print(f'accuracy dtree   : {accuracy_dtree}')
  print(f'accuracy rforest : {accuracy_rforest}')
  
  #print(f'confusion matrix bnb:\n{confusion_matrix(y_test, predicted_bnb, labels=["Positivo", "Negativo", "Neutro", "Irrelevante"])}')
  
  count_g += accuracy_gnb
  count_b += accuracy_bnb
  count_dtree += accuracy_dtree
  count_rforest += accuracy_rforest

print(f'erro medio gnb     : {count_g / 4}')
print(f'erro medio bnb     : {count_b / 4}')
print(f'erro medio dtree   : {count_dtree / 4}')
print(f'erro medio rforest : {count_rforest / 4}')
# Out:
# accuracy gnb     : 0.5416666666666666
# accuracy bnb     : 0.6190476190476191
# accuracy dtree   : 0.5892857142857143
# accuracy rforest : 0.6011904761904762
# accuracy gnb     : 0.5238095238095238
# accuracy bnb     : 0.6428571428571429
# accuracy dtree   : 0.5714285714285714
# accuracy rforest : 0.6369047619047619
# accuracy gnb     : 0.6036585365853658
# accuracy bnb     : 0.7012195121951219
# accuracy dtree   : 0.5914634146341463
# accuracy rforest : 0.6036585365853658
# accuracy gnb     : 0.5304878048780488
# accuracy bnb     : 0.6463414634146342
# accuracy dtree   : 0.5609756097560976
# accuracy rforest : 0.6585365853658537
# erro medio gnb     : 0.5499056329849012
# erro medio bnb     : 0.6523664343786295
# erro medio dtree   : 0.5782883275261324
# erro medio rforest : 0.6250725900116144

# %% [markdown]
# # Usando Analise de sentimento do Watson

# %%
#Instalando e importando lib
import pandas as pd
# !pip install ibm_watson
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions, KeywordsOptions
# Out:
# Requirement already satisfied: ibm_watson in /usr/local/lib/python3.6/dist-packages (3.0.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.6/dist-packages (from ibm_watson) (2.5.3)
# Requirement already satisfied: websocket-client==0.48.0 in /usr/local/lib/python3.6/dist-packages (from ibm_watson) (0.48.0)
# Requirement already satisfied: ibm-cloud-sdk-core>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from ibm_watson) (0.4.2)
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from ibm_watson) (2.21.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.5.3->ibm_watson) (1.12.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.0->ibm_watson) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.0->ibm_watson) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.0->ibm_watson) (2019.3.9)

# %%
#Autenticação

natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2018-11-16',
    iam_apikey='OyiIoauG0YZQT96rreVzyRibbOPFlfmOb0Mj4uLSe72r',
    url='https://gateway.watsonplatform.net/natural-language-understanding/api')

# %%
predicted = []
watson_df = tweets_df[tweets_df.sentiment != "Irrelevante"]
for tweet in watson_df["text"]:
  try:
    response = natural_language_understanding.analyze(
        text=tweet,
        features=Features(
            keywords=KeywordsOptions(emotion=True, sentiment=True,
                                     limit=1))).get_result()
    predicted.append(response['keywords'][0]['sentiment']['label'])
  except Exception as e:
    predicted.append("neutral")
print(predicted)
# Out:
# ['positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'neutral', 'positive', 'negative', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'neutral', 'neutral', 'negative', 'positive', 'positive', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'negative', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'positive', 'negative', 'negative', 'positive', 'neutral', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'negative', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'neutral', 'negative', 'positive', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'negative', 'neutral', 'neutral', 'positive', 'positive', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'positive', 'neutral', 'neutral', 'negative', 'negative', 'negative', 'positive', 'neutral', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'negative', 'positive', 'negative', 'positive', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'neutral', 'neutral', 'neutral', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'positive', 'neutral', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'positive', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'neutral', 'neutral', 'neutral', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'neutral', 'negative', 'negative', 'negative', 'negative', 'positive', 'neutral', 'negative', 'neutral', 'negative', 'neutral', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'negative', 'neutral', 'neutral', ...

# %%
translate_dict = {
    "positive": "Positivo",
    "negative": "Negativo",
    "neutral": "Neutro"
}
y = tweets_df["sentiment"]
y = list(filter(lambda x: x != "Irrelevante", y))
predicted_t = [translate_dict[x] for x in predicted]
score = accuracy_score(predicted_t, y)

# %%
score
# Out:
# 0.5983935742971888

# %% [markdown]
# #Google Natural Language API

# %%
import os
import time
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="My Project-7811bb2e5cc6.json"

# Imports the Google Cloud client library
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# Instantiates a client
client = language.LanguageServiceClient()

print("text,score,magnitude,sentiment")

for index in range(tweets_df.shape[0]):
  # The text to analyze
  text = tweets_df.iloc[index]["text"]
  classification = tweets_df.iloc[index]["sentiment"]
  document = types.Document(
      content=text,
      type=enums.Document.Type.PLAIN_TEXT)

  # Detects the sentiment of the text
  sentiment = client.analyze_sentiment(document=document).document_sentiment
#   print(sentiment)
#   print('Text: {}'.format(text))
#   print('Sentiment:: score: {}, magnitude: {}'.format(sentiment.score, sentiment.magnitude))
  print(f'"{text}",{sentiment.score},{sentiment.magnitude},{classification}')
  time.sleep(0.5)

# %%
#load google dataframe
google_df = pd.read_csv("https://raw.githubusercontent.com/Softex-Recife/hands-on-nlp/master/google_nlapi.csv")
google_df = google_df[google_df.sentiment != "Irrelevante"]
X = google_df[["score", "magnitude"]]
print(X.shape)
y = google_df["sentiment"]
print(y.shape)
# Out:
# (498, 2)
# (498,)

# %%
from sklearn import tree
# X = google_df["score"] + google_df["magnitude"]

kfs.get_n_splits(X, y)

count_dtree = 0

for train_index, test_index in kfs.split(X, y):
  X_train, X_test = X.iloc[train_index], X.iloc[test_index]
  y_train, y_test = y.iloc[train_index], y.iloc[test_index]
  
  dtree.fit(X_train, y_train)
  y_predicted = dtree.predict(X_test)
  accuracy = accuracy_score(y_test, y_predicted)
  

  print(f'accuracy dtree   : {accuracy_dtree}')
  
  #print(f'confusion matrix bnb:\n{confusion_matrix(y_test, predicted_bnb, labels=["Positivo", "Negativo", "Neutro", "Irrelevante"])}')

  count_dtree += accuracy_dtree


print(f'erro medio dtree   : {count_dtree / 4}')
# Out:
# accuracy dtree   : 0.5609756097560976
# accuracy dtree   : 0.5609756097560976
# accuracy dtree   : 0.5609756097560976
# accuracy dtree   : 0.5609756097560976
# erro medio dtree   : 0.5609756097560976
